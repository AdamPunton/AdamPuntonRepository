# %% [markdown]
# #### Create a dictionary with the same structure as the dictionary we created in the in class project for 10 professionals or specialists that you admire. The dictionary should include keys that identify the name of the professional, their area of expertise, a short biography, and a link to their website (or social media profile if no website is available). Print the dataframe and save this dataframe as a csv.

# %%
professional_dct = {"Bullock, David":{"Area of Expertise":"Agribusiness and Applied Economics",
                                     "Short Biography":"Dr. David W. Bullock is a Research Associate Professor affiliated with the Center for Trading and Risk at NDSU. His research interests include futures and options markets, over-the-counter derivatives, trading, risk management, agrifinance, Monte Carlo simulation, and Big Data applications in agriculture.",
                                     "Link to Website":"david.w.bullock@ndsu.edu"},
                   }
professional_dct
# Out:
# {'Bullock, David': {'Area of Expertise': 'Agribusiness and Applied Economics',
#   'Short Biography': 'Dr. David W. Bullock is a Research Associate Professor affiliated with the Center for Trading and Risk at NDSU. His research interests include futures and options markets, over-the-counter derivatives, trading, risk management, agrifinance, Monte Carlo simulation, and Big Data applications in agriculture.',
#   'Link to Website': 'david.w.bullock@ndsu.edu'}}

# %%
pd.DataFrame(professional_dct).T
# Out:
#                                  Area of Expertise           Link to Website  \
# Bullock, David  Agribusiness and Applied Economics  david.w.bullock@ndsu.edu
#
#                                                   Short Biography
# Bullock, David  Dr. David W. Bullock is a Research Associate P...

# %%
import pandas as pd

# %%
professional_df = pd.read_csv("Professionals.csv")
professional_df
# Out:
#                Name                                  Area of Expertise  \
# 0     David Bullock                 Agribusiness and Applied Economics
# 1        James Dean                 Agribusiness and Applied Economics
# 2     Robert Hearne                 Agribusiness and Applied Economics
# 3         Tim Petry            Associate Professor/Livestock Economist
# 4  David Ripplinger  Associate Professor/Extension Bioproducts/Bioe...
# 5   Kristi Schweiss  Assistant Director, Quentin Burdick Center for...
# 6  Sandro Steinbach  Associate Professor/Director for Agricultural ...
# 7    William Wilson                 Agribusiness and Applied Economics
# 8    Ahmad Al Asady                  Assistant Professor of Management
# 9    Fariz Huseynov                               Professor of Finance
#
#                                      Short Biography  \
# 0  Dr. David W. Bullock is a Research Associate P...
# 1  B.S. Economics, Lubbock Christian University, ...
# ...

# %%
professional_df.dropna()
# Out:
#                Name                                  Area of Expertise  \
# 0     David Bullock                 Agribusiness and Applied Economics
# 1        James Dean                 Agribusiness and Applied Economics
# 2     Robert Hearne                 Agribusiness and Applied Economics
# 3         Tim Petry            Associate Professor/Livestock Economist
# 4  David Ripplinger  Associate Professor/Extension Bioproducts/Bioe...
# 5   Kristi Schweiss  Assistant Director, Quentin Burdick Center for...
# 6  Sandro Steinbach  Associate Professor/Director for Agricultural ...
# 8    Ahmad Al Asady                  Assistant Professor of Management
# 9    Fariz Huseynov                               Professor of Finance
#
#                                      Short Biography  \
# 0  Dr. David W. Bullock is a Research Associate P...
# 1  B.S. Economics, Lubbock Christian University, ...
# 2  B.A. Economics, Georgetown University (1980), ...
# ...
