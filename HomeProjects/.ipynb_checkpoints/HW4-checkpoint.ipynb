# %% [markdown]
# ### Homework 4

# %% [markdown]
# 1. Create a function that calculates the length of a list without using len()
#  and returns this value. Create a list and pass it to the function to find its
#  length.

# %%
def list_length(lst):
    number = 0
    for element in lst:
        number += 1
    return number

# %%
example_list = [0,58,794,9444,5558,2,6,7,8,6]
list_length(example_list)
# Out:
# 10

# %% [markdown]
# 2. Create a function that performs dot multiplication on two vectors (lists),
#  such that if list1 = [x1,x2,x3] and list2 = [y1,y2,y3],
#  dot_product_list1_list2 = [x1y1, x2y2, x3y3] and returns this list.
# Pass two lists of the same length to this function.

# %%
def dot_mult_list1_list2(list1, list2):
    result = []
    for i in range(len(list1)):
        result.append(list1[i] * list2[i])
        
    return result

# %%
list1 = [5,6,7]
list2 = [9,10,11]
dot_mult_list1_list2(list1, list2)
# Out:
# [45, 60, 77]

# %% [markdown]
# 3. In a single line, pass two lists of the same length to the function from
#  question 2 and pass the instance of that function to the function from
#  question 1. What is the length of dot_product_list1_list2?

# %%
list_length(dot_mult_list1_list2([1,2,3],[4,5,6]))
# Out:
# 3

# %% [markdown]
# 4. Create two unique lists using generator functions and pass them to the
#  function created in question 2.

# %%
import random

list_1 = random_list
list_2 = power_num

random_list = [round(random.random() * 100, 2) for i in range(15)]
power_num = [(i ** 2) for i in range(15)]

dot_mult = dot_mult_list1_list2(list_1, list_2)
print("Dot Multiplication:", dot_mult)
print("List1:", list_1)
print("List2:", list_2)
# Out:
# Dot Multiplication: [0.0, 31.27, 184.16, 59.49, 748.96, 462.0, 1908.36, 4383.05, 1545.6, 5501.52, 4820.0, 4953.74, 13455.36, 4054.31, 876.12]
# List1: [0.05, 31.27, 46.04, 6.61, 46.81, 18.48, 53.01, 89.45, 24.15, 67.92, 48.2, 40.94, 93.44, 23.99, 4.47]
# List2: [0, 1, 4, 9, 16, 25, 36, 49, 64, 81, 100, 121, 144, 169, 196]

# %% [markdown]
# 5. Create a function that checks the types of elements in a list. For example,
#  if a list contains a string, an integer, and a float, this function should
#  return a list that contains identifies these three types: [str, int, float]

# %%
def type_list(lst):
    result=[]
    for i in lst:
        result.append(type(i).__name__)
    return result

# %%
result = type_list([1,1.0,"88"])
print(result)
# Out:
# ['int', 'float', 'str']

# %% [markdown]
# 6. In a single line, pass a list with at least 4 different types to the function
#  from question 5 and pass the result to the funciton measuring length.

# %%
list_length(type_list([1,2.,"Hi",False]))
# Out:
# 4

# %% [markdown]
# 7. Create a class that houses each of the functions (now methods) that you have created.
#  Create an instance of that class and use each of the methods from the class.

# %%
class methods:
    def list_length(lst):
        number = 0
        for element in lst:
            number += 1
        return number

    def dot_mult_list1_list2(listA, listB):
        result = []
        for i in range(len(listA)):
            result.append(listA[i] * listB[i])
        return result

    def type_list(*args):
        result=[]
        for i in args:
            result.append(type(i).__name__)
        return result

    def random_gen_list(lst): 
        random_list = [round(random.random() * 100, 2) for i in range(15)]
        return random_list

    def power_gen_list(lst):
        power_num = [(i ** 2) for i in range(15)]
        return power_num

# %%
list1 = methods.random_gen_list(0)
print("Random List:", list1)

list2 = methods.power_gen_list(0)
print("Power List:", list2)

length1 = methods.list_length(list1)
length2 = methods.list_length(list2)
print("Length1:", length1, "Length2:", length2)

dot_mult = methods.dot_mult_list1_list2(list1, list2)
print("Dot Mult:", dot_mult)

type_list = methods.type_list(list1)
print(type_list)
# Out:
# Random List: [76.05, 7.37, 47.55, 92.96, 53.85, 70.53, 73.05, 10.35, 86.93, 21.31, 17.74, 79.56, 87.85, 69.7, 28.3]
# Power List: [0, 1, 4, 9, 16, 25, 36, 49, 64, 81, 100, 121, 144, 169, 196]
# Length1: 15 Length2: 15
# Dot Mult: [0.0, 7.37, 190.2, 836.64, 861.6, 1763.25, 2629.7999999999997, 507.15, 5563.52, 1726.11, 1773.9999999999998, 9626.76, 12650.4, 11779.300000000001, 5546.8]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_21108\433622756.py in <module>
#      12 print("Dot Mult:", dot_mult)
#      13
# ---> 14 type_list = methods.type_list(list1)
#      15 print(type_list)
#
# ~\AppData\Local\Temp\ipykernel_21108\142448992.py in type_list(*args)
#      15         result=[]
#      16         for i in args:
# ---> 17             result.append(type(i).__name__)
#      18         return result
#      19
#
# TypeError: 'list' object is not callable

# %% [markdown]
# 1. Download and plot 3 apparently related sets of data with at least. Each set should contain at least two related variables. You should explain how variables in each set of data are related. Plot each set using the scatter plot function and the line graph function. For example, you might the obseved rate of unemployement and the natural rate of unemployment in the same graph. To find data, search for data at FRED and use the code associated with the data. For example, the CPI measure that includes urban items is identified by the code, CPIAUCSL.

# %%
# !pip install pandas-datareader

import os
import pandas as pd
import pandas_datareader.data as web
import datetime
import numpy as np
import matplotlib.pyplot as plt
# Out:
# Requirement already satisfied: pandas-datareader in c:\users\adamp\anaconda3\lib\site-packages (0.10.0)
# Requirement already satisfied: pandas>=0.23 in c:\users\adamp\anaconda3\lib\site-packages (from pandas-datareader) (1.4.4)
# Requirement already satisfied: lxml in c:\users\adamp\anaconda3\lib\site-packages (from pandas-datareader) (4.9.1)
# Requirement already satisfied: requests>=2.19.0 in c:\users\adamp\anaconda3\lib\site-packages (from pandas-datareader) (2.28.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\adamp\anaconda3\lib\site-packages (from pandas>=0.23->pandas-datareader) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\adamp\anaconda3\lib\site-packages (from pandas>=0.23->pandas-datareader) (2022.1)
# Requirement already satisfied: numpy>=1.18.5 in c:\users\adamp\anaconda3\lib\site-packages (from pandas>=0.23->pandas-datareader) (1.21.5)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\adamp\anaconda3\lib\site-packages (from requests>=2.19.0->pandas-datareader) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\adamp\anaconda3\lib\site-packages (from requests>=2.19.0->pandas-datareader) (1.26.11)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\adamp\anaconda3\lib\site-packages (from requests>=2.19.0->pandas-datareader) (2022.9.14)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\adamp\anaconda3\lib\site-packages (from requests>=2.19.0->pandas-datareader) (2.0.4)
# Requirement already satisfied: six>=1.5 in c:\users\adamp\anaconda3\lib\site-packages (from python-dateutil>=2.8.1->pandas>=0.23->pandas-datareader) (1.16.0)

# %%
data_codes  = {"MAFAINUSA646N",
               "ASPUS"}
start = datetime.datetime(1990, 1, 1)
end = datetime.datetime.today()
data = web.DataReader(data_codes, "fred", start, end).resample("A").mean()
data.rename(columns={"MAFAINUSA646N": "Mean Family Income in the United States",
                      "ASPUS": "Average Sales Price of Houses Sold for the United States"}, inplace = True)
data
# Out:
#             Mean Family Income in the United States  \
# DATE
# 1990-12-31                                  42652.0
# 1991-12-31                                  43237.0
# 1992-12-31                                  44221.0
# 1993-12-31                                  47221.0
# 1994-12-31                                  49340.0
# 1995-12-31                                  51353.0
# 1996-12-31                                  53676.0
# 1997-12-31                                  56902.0
# 1998-12-31                                  59589.0
# 1999-12-31                                  62567.0
# 2000-12-31                                  65773.0
# 2001-12-31                                  66863.0
# 2002-12-31                                  66970.0
# 2003-12-31                                  68563.0
# 2004-12-31                                  70389.0
# 2005-12-31                                  73304.0
# 2006-12-31                                  77315.0
# 2007-12-31                                  78845.0
# 2008-12-31                                  79634.0
# 2009-12-31                                  78538.0
# 2010-12-31                                  78180.0
# 2011-12-31                                  81007.0
# 2012-12-31                                  82843.0
# 2013-12-31                                  87671.0
# 2014-12-31                                  88765.0
# 2015-12-31                                  92673.0
# 2016-12-31                                  97357.0
# 2017-12-31                                 103218.0
# 2018-12-31                                 106045.0
# 2019-12-31                                 116735.0
# 2020-12-31                                 115310.0
# 2021-12-31                                 121840.0
# 2022-12-31                                      NaN
#
#             Average Sales Price of Houses Sold for the United States
# DATE
# 1990-12-31                                           149075.0
# 1991-12-31                                           147275.0
# 1992-12-31                                           144675.0
# 1993-12-31                                           147475.0
# 1994-12-31                                           154175.0
# 1995-12-31                                           157750.0
# 1996-12-31                                           165525.0
# 1997-12-31                                           174875.0
# 1998-12-31                                           181150.0
# 1999-12-31                                           194675.0
# 2000-12-31                                           205375.0
# 2001-12-31                                           211050.0
# 2002-12-31                                           226700.0
# 2003-12-31                                           244550.0
# 2004-12-31                                           272125.0
# 2005-12-31                                           291275.0
# 2006-12-31                                           303900.0
# 2007-12-31                                           309800.0
# 2008-12-31                                           289075.0
# 2009-12-31                                           269350.0
# 2010-12-31                                           272025.0
# 2011-12-31                                           264600.0
# 2012-12-31                                           288225.0
# 2013-12-31                                           321650.0
# 2014-12-31                                           345450.0
# 2015-12-31                                           350450.0
# 2016-12-31                                           359650.0
# 2017-12-31                                           381150.0
# 2018-12-31                                           382475.0
# 2019-12-31                                           379875.0
# 2020-12-31                                           389800.0
# 2021-12-31                                           457375.0
# 2022-12-31                                           531300.0

# %%
fig, ax = plt.subplots(figsize = (20,10))
data.plot.line(ax=ax)
# Out:
# <AxesSubplot:xlabel='DATE'>

# %% [markdown]
# The connection between mean family income in the US and average sales prices of houses sold for the US used to be a lot closer correlated but the bubble in 2008 happened and the housing market hasn't been the same. The average house price theoretically should go up as the mean family income goes up because the consumers that are looking for houses tend to be families. The housing market is tied to many things and not so much family income anymore.

# %%
data_codes  = {"HOUST",
               "HSN1F"}
start = datetime.datetime(1990, 1, 1)
end = datetime.datetime.today()
data1 = web.DataReader(data_codes, "fred", start, end).resample("A").mean()
data1.rename(columns={"HOUST": "New Privately-Owned Housing Units Started: Total Units",
                      "HSN1F": "New One Family Houses Sold: United States"}, inplace = True)
data1
# Out:
#             New One Family Houses Sold: United States  \
# DATE
# 1990-12-31                                 532.833333
# 1991-12-31                                 509.333333
# 1992-12-31                                 613.500000
# 1993-12-31                                 674.416667
# 1994-12-31                                 667.250000
# 1995-12-31                                 669.500000
# 1996-12-31                                 755.750000
# 1997-12-31                                 806.333333
# 1998-12-31                                 889.416667
# 1999-12-31                                 878.500000
# 2000-12-31                                 880.250000
# 2001-12-31                                 907.250000
# 2002-12-31                                 976.166667
# 2003-12-31                                1090.666667
# 2004-12-31                                1200.833333
# 2005-12-31                                1278.916667
# 2006-12-31                                1049.333333
# 2007-12-31                                 768.666667
# 2008-12-31                                 482.166667
# 2009-12-31                                 374.250000
# 2010-12-31                                 321.250000
# 2011-12-31                                 306.416667
# 2012-12-31                                 368.083333
# 2013-12-31                                 429.833333
# 2014-12-31                                 440.250000
# 2015-12-31                                 502.583333
# 2016-12-31                                 560.500000
# 2017-12-31                                 614.666667
# 2018-12-31                                 613.916667
# 2019-12-31                                 683.166667
# 2020-12-31                                 831.250000
# 2021-12-31                                 769.416667
# 2022-12-31                                 640.833333
# 2023-12-31                                 670.000000
#
#             New Privately-Owned Housing Units Started: Total Units
# DATE
# 1990-12-31                                        1203.166667
# 1991-12-31                                        1008.750000
# 1992-12-31                                        1201.416667
# 1993-12-31                                        1291.583333
# 1994-12-31                                        1446.000000
# 1995-12-31                                        1361.000000
# 1996-12-31                                        1468.666667
# 1997-12-31                                        1474.583333
# 1998-12-31                                        1621.166667
# 1999-12-31                                        1647.250000
# 2000-12-31                                        1573.333333
# 2001-12-31                                        1601.166667
# 2002-12-31                                        1710.250000
# 2003-12-31                                        1853.750000
# 2004-12-31                                        1949.500000
# 2005-12-31                                        2072.916667
# 2006-12-31                                        1811.916667
# 2007-12-31                                        1341.833333
# 2008-12-31                                         900.000000
# 2009-12-31                                         554.000000
# 2010-12-31                                         585.500000
# 2011-12-31                                         611.916667
# 2012-12-31                                         783.750000
# 2013-12-31                                         928.166667
# 2014-12-31                                        1000.250000
# 2015-12-31                                        1106.750000
# 2016-12-31                                        1177.083333
# 2017-12-31                                        1204.666667
# 2018-12-31                                        1247.333333
# 2019-12-31                                        1291.000000
# 2020-12-31                                        1395.083333
# 2021-12-31                                        1605.166667
# 2022-12-31                                        1555.583333
# 2023-12-31                                        1309.000000

# %%
fig, ax = plt.subplots(figsize = (20,10))
data1.plot.line(ax=ax)
# Out:
# <AxesSubplot:xlabel='DATE'>

# %% [markdown]
# As more houses get sold, more housing gets started. You also can see when these two graphs get close during a housing recession. The relationship between housing being started and sold could be a leading indicator for house sale prices.

# %%
data_codes  = {"DGS30",
               "MORTGAGE30US"}
start = datetime.datetime(1990, 1, 1)
end = datetime.datetime.today()
data2 = web.DataReader(data_codes, "fred", start, end).resample("A").mean()
data2.rename(columns={"DGS30": "30-Year Fixed Rate Mortgage Average in the United States",
                      "MORTGAGE30US": "Market Yield on U.S. Treasury Securities at 30-Year Constant Maturity"}, inplace = True)
data2['dif_column'] =  data2['Market Yield on U.S. Treasury Securities at 30-Year Constant Maturity'] - data2['30-Year Fixed Rate Mortgage Average in the United States']

data2
# Out:
#             Market Yield on U.S. Treasury Securities at 30-Year Constant Maturity  \
# DATE
# 1990-12-31                                          10.129423
# 1991-12-31                                           9.246538
# 1992-12-31                                           8.390189
# 1993-12-31                                           7.314615
# 1994-12-31                                           8.380769
# 1995-12-31                                           7.934615
# 1996-12-31                                           7.806154
# 1997-12-31                                           7.598846
# 1998-12-31                                           6.942642
# 1999-12-31                                           7.440000
# 2000-12-31                                           8.053462
# 2001-12-31                                           6.967885
# 2002-12-31                                           6.537308
# 2003-12-31                                           5.826981
# 2004-12-31                                           5.839231
# 2005-12-31                                           5.866731
# 2006-12-31                                           6.413269
# 2007-12-31                                           6.337308
# 2008-12-31                                           6.027170
# 2009-12-31                                           5.036538
# 2010-12-31                                           4.689808
# 2011-12-31                                           4.447885
# 2012-12-31                                           3.657500
# 2013-12-31                                           3.975577
# 2014-12-31                                           4.168868
# 2015-12-31                                           3.850577
# 2016-12-31                                           3.654038
# 2017-12-31                                           3.989808
# 2018-12-31                                           4.544615
# 2019-12-31                                           3.935769
# 2020-12-31                                           3.111698
# 2021-12-31                                           2.957692
# 2022-12-31                                           5.344038
# 2023-12-31                                           6.307778
#
#             30-Year Fixed Rate Mortgage Average in the United States  \
# DATE
# 1990-12-31                                           8.610000
# 1991-12-31                                           8.139160
# 1992-12-31                                           7.665976
# 1993-12-31                                           6.591520
# 1994-12-31                                           7.372691
# 1995-12-31                                           6.880160
# 1996-12-31                                           6.706310
# 1997-12-31                                           6.606760
# 1998-12-31                                           5.576800
# 1999-12-31                                           5.872231
# 2000-12-31                                           5.940637
# 2001-12-31                                           5.494839
# 2002-12-31                                           5.440720
# 2003-12-31                                           5.109200
# 2004-12-31                                           5.131920
# 2005-12-31                                           4.560680
# 2006-12-31                                           4.879520
# 2007-12-31                                           4.838287
# 2008-12-31                                           4.277530
# 2009-12-31                                           4.076680
# 2010-12-31                                           4.251076
# 2011-12-31                                           3.910800
# 2012-12-31                                           2.921680
# 2013-12-31                                           3.446160
# 2014-12-31                                           3.338160
# 2015-12-31                                           2.840996
# 2016-12-31                                           2.594400
# 2017-12-31                                           2.894040
# 2018-12-31                                           3.111566
# 2019-12-31                                           2.580400
# 2020-12-31                                           1.556135
# 2021-12-31                                           2.055578
# 2022-12-31                                           3.113133
# 2023-12-31                                           3.744634
#
#             dif_column
# DATE
# 1990-12-31    1.519423
# 1991-12-31    1.107378
# 1992-12-31    0.724213
# 1993-12-31    0.723095
# 1994-12-31    1.008078
# 1995-12-31    1.054455
# 1996-12-31    1.099844
# 1997-12-31    0.992086
# 1998-12-31    1.365842
# 1999-12-31    1.567769
# 2000-12-31    2.112824
# 2001-12-31    1.473046
# 2002-12-31    1.096588
# 2003-12-31    0.717781
# 2004-12-31    0.707311
# 2005-12-31    1.306051
# 2006-12-31    1.533749
# 2007-12-31    1.499021
# 2008-12-31    1.749640
# 2009-12-31    0.959858
# 2010-12-31    0.438732
# 2011-12-31    0.537085
# 2012-12-31    0.735820
# 2013-12-31    0.529417
# 2014-12-31    0.830708
# 2015-12-31    1.009581
# 2016-12-31    1.059638
# 2017-12-31    1.095768
# 2018-12-31    1.433049
# 2019-12-31    1.355369
# 2020-12-31    1.555563
# 2021-12-31    0.902115
# 2022-12-31    2.230906
# 2023-12-31    2.563144

# %%
fig, ax = plt.subplots(figsize = (20,10))
data2.plot.line(ax=ax)
# Out:
# <AxesSubplot:xlabel='DATE'>

# %% [markdown]
# The U.S. 30-year treasury and the 30-year fixed rate mortgage are fairly correlated and historically have a spread of 0.75 to 1.5. Today it is at 2.5 which is a historically high level, indicating that either the market has factored in future rate hikes or mortgages will come back down to historical levels.

# %% [markdown]
# 2. Create a correlation matrix for quarterly observations of Nominal GDP, Real GDP, the Price Level (CPI or GDP Deflator), the quantity of currency in circulation and the federal funds rate for as large of a date range as possible. Then, calculate the year-over-year percent change for each each variable and save the results as variables in the same dataframe. Create a correlation matrix for these new variables.

# %%
data_codes  = {"NGDPPOT",
               "GDPC1",
              "A191RD3A086NBEA",
              "CURRCIR",
              "FEDFUNDS"}
start = datetime.datetime(1954, 1, 1)
end = datetime.datetime.today()
data = web.DataReader(data_codes, "fred", start, end).resample("A").mean()
data.rename(columns={"NGDPPOT": "Nominal Potential Gross Domestic Product",
                      "GDPC1": "Real Gross Domestic Product",
                    "A191RD3A086NBEA": "Gross domestic product (implicit price deflator)",
                    "CURRCIR": "Currency in Circulation",
                    "FEDFUNDS": "Federal Funds Effective Rate"}, inplace = True)
data
# Out:
#             Currency in Circulation  Real Gross Domestic Product  \
# DATE
# 1954-12-31                30.028167                   2681.85400
# 1955-12-31                30.248583                   2873.15975
# 1956-12-31                30.686250                   2934.39125
# 1957-12-31                31.002750                   2996.17800
# 1958-12-31                31.176167                   2973.98225
# ...                             ...                          ...
# 2019-12-31              1745.099167                  19036.05225
# 2020-12-31              1947.410083                  18509.14275
# 2021-12-31              2168.075667                  19609.81175
# 2022-12-31              2270.853750                  20015.37925
# 2023-12-31              2298.679000                          NaN
#
#             Gross domestic product (implicit price deflator)  \
# DATE
# 1954-12-31                                            14.563
# 1955-12-31                                            14.809
# 1956-12-31                                            15.313
# 1957-12-31                                            15.821
# 1958-12-31                                            16.181
# ...                                                      ...
# 2019-12-31                                           112.318
# 2020-12-31                                           113.784
# 2021-12-31                                           118.895
# 2022-12-31                                           127.224
# 2023-12-31                                               NaN
#
#             Federal Funds Effective Rate  \
# DATE
# 1954-12-31                      1.008333
# 1955-12-31                      1.785000
# 1956-12-31                      2.728333
# 1957-12-31                      3.105000
# 1958-12-31                      1.572500
# ...                                  ...
# 2019-12-31                      2.158333
# 2020-12-31                      0.375833
# 2021-12-31                      0.080000
# 2022-12-31                      1.683333
# 2023-12-31                      4.450000
#
#             Nominal Potential Gross Domestic Product
# DATE
# 1954-12-31                                395.342364
# 1955-12-31                                412.306623
# 1956-12-31                                437.720407
# 1957-12-31                                466.173172
# 1958-12-31                                493.618920
# ...                                              ...
# 2019-12-31                              21436.952369
# 2020-12-31                              22087.987945
# 2021-12-31                              23408.615000
# 2022-12-31                              25107.290000
# 2023-12-31                              25874.050000
#
# [70 rows x 5 columns]

# %%
corr_DF = data.corr().round(2)
corr_DF
# Out:
#                                                   Currency in Circulation  \
# Currency in Circulation                                              1.00
# Real Gross Domestic Product                                          0.93
# Gross domestic product (implicit price deflator)                     0.90
# Federal Funds Effective Rate                                        -0.51
# Nominal Potential Gross Domestic Product                             0.97
#
#                                                   Real Gross Domestic Product  \
# Currency in Circulation                                                  0.93
# Real Gross Domestic Product                                              1.00
# Gross domestic product (implicit price deflator)                         0.99
# Federal Funds Effective Rate                                            -0.44
# Nominal Potential Gross Domestic Product                                 0.98
#
#                                                   Gross domestic product (implicit price deflator)  \
# Currency in Circulation                                                                       0.90
# Real Gross Domestic Product                                                                   0.99
# Gross domestic product (implicit price deflator)                                              1.00
# Federal Funds Effective Rate                                                                 -0.39
# Nominal Potential Gross Domestic Product                                                      0.97
#
#                                                   Federal Funds Effective Rate  \
# Currency in Circulation                                                  -0.51
# Real Gross Domestic Product                                              -0.44
# Gross domestic product (implicit price deflator)                         -0.39
# Federal Funds Effective Rate                                              1.00
# Nominal Potential Gross Domestic Product                                 -0.50
#
#                                                   Nominal Potential Gross Domestic Product
# Currency in Circulation                                                               0.97
# Real Gross Domestic Product                                                           0.98
# Gross domestic product (implicit price deflator)                                      0.97
# Federal Funds Effective Rate                                                         -0.50
# Nominal Potential Gross Domestic Product                                              1.00

# %%
import numpy as np
import matplotlib.pyplot as plt
import os
from matplotlib.backends.backend_pdf import PdfPages

def corr_matrix_heatmap(data, dim = 20, pp = None):
    fig, ax = plt.subplots(figsize = (dim,dim))
    # Dividing the square into k columns and k rows
    # First, use a data type to allow the program to divdie the square
    im = ax.imshow(data, norm = plt.cm.colors.Normalize(-1,1), cmap = "seismic")
    labels = data.keys()
    num_vars = len(labels)
    tick_labels = [label.replace(" ","\n") for label in labels]
    tick_font_size = 120 / num_vars
    val_font_size = 200 / num_vars
    plt.rcParams.update({'font.size': tick_font_size})
    x_ticks = np.arange(num_vars)
    plt.xticks(x_ticks, tick_labels, fontsize = tick_font_size, rotation = 90)
    y_ticks = np.arange(num_vars)
    plt.yticks(y_ticks, tick_labels, fontsize = tick_font_size)
    # put all of the options chosen above to use and create the correlation figure
    for i in range(len(labels)):
        for j in range(len(labels)):
            text = ax.text(i, j, str(round(data.values[i][j],2)),  
                           fontsize= val_font_size, ha="center",   
                           va="center", color = "w")
    title_font = {"fontname":"Times New Roman"}  
    plt.title("Correlation", fontsize = 50, **title_font)  
    
             # print(i, labels[i], j, labels[j], data.values[i][j])
    cbar = fig.colorbar(im)
    plt.show()
    if pp != None:
        pp.savefig(fig, bbox_inches="tight")
    plt.close()

corr_data = data.corr()
corr_matrix_heatmap(data.corr())

# %%
data_y = pd.DataFrame()
data_y['Nominal GDP YoY'] = data['Nominal Potential Gross Domestic Product'].pct_change(periods=1) * 100
data_y['Real GDP YoY'] = data['Real Gross Domestic Product'].pct_change(periods=1) * 100
data_y['Price Level YoY'] = data['Gross domestic product (implicit price deflator)'].pct_change(periods=1) * 100
data_y['Currency in Circulation YoY'] = data['Currency in Circulation'].pct_change(periods=1) * 100
data_y['Federal Funds Rate YoY'] = data['Federal Funds Effective Rate'].pct_change(periods=1) * 100
data_y
# Out:
#             Nominal GDP YoY  Real GDP YoY  Price Level YoY  \
# DATE
# 1954-12-31              NaN           NaN              NaN
# 1955-12-31         4.291030      7.133339         1.689212
# 1956-12-31         6.163807      2.131155         3.403336
# 1957-12-31         6.500214      2.105607         3.317443
# 1958-12-31         5.887458     -0.740802         2.275457
# ...                     ...           ...              ...
# 2019-12-31         3.732753      2.294439         1.793563
# 2020-12-31         3.036978     -2.767956         1.305223
# 2021-12-31         5.978938      5.946623         4.491844
# 2022-12-31         7.256623      2.068187         7.005341
# 2023-12-31         3.053934      0.000000         0.000000
#
#             Currency in Circulation YoY  Federal Funds Rate YoY
# DATE
# 1954-12-31                          NaN                     NaN
# 1955-12-31                     0.734033               77.024793
# 1956-12-31                     1.446900               52.847806
# 1957-12-31                     1.031407               13.805742
# 1958-12-31                     0.559359              -49.355878
# ...                                 ...                     ...
# 2019-12-31                     5.033824               17.834395
# 2020-12-31                    11.593090              -82.586873
# 2021-12-31                    11.331233              -78.713969
# 2022-12-31                     4.740521             2004.166667
# 2023-12-31                     1.225321              164.356436
#
# [70 rows x 5 columns]

# %%
corr_DF = data_y.corr().round(2)
corr_DF
# Out:
#                              Nominal GDP YoY  Real GDP YoY  Price Level YoY  \
# Nominal GDP YoY                         1.00          0.06             0.93
# Real GDP YoY                            0.06          1.00            -0.10
# Price Level YoY                         0.93         -0.10             1.00
# Currency in Circulation YoY             0.31         -0.02             0.38
# Federal Funds Rate YoY                  0.04          0.01             0.19
#
#                              Currency in Circulation YoY  \
# Nominal GDP YoY                                     0.31
# Real GDP YoY                                       -0.02
# Price Level YoY                                     0.38
# Currency in Circulation YoY                         1.00
# Federal Funds Rate YoY                             -0.13
#
#                              Federal Funds Rate YoY
# Nominal GDP YoY                                0.04
# Real GDP YoY                                   0.01
# Price Level YoY                                0.19
# Currency in Circulation YoY                   -0.13
# Federal Funds Rate YoY                         1.00

# %%
import numpy as np
import matplotlib.pyplot as plt
import os
from matplotlib.backends.backend_pdf import PdfPages

def corr_matrix_heatmap(data, dim = 20, pp = None):
    fig, ax = plt.subplots(figsize = (dim,dim))
    # Dividing the square into k columns and k rows
    # First, use a data type to allow the program to divdie the square
    im = ax.imshow(data, norm = plt.cm.colors.Normalize(-1,1), cmap = "seismic")
    labels = data.keys()
    num_vars = len(labels)
    tick_labels = [label.replace(" ","\n") for label in labels]
    tick_font_size = 120 / num_vars
    val_font_size = 200 / num_vars
    plt.rcParams.update({'font.size': tick_font_size})
    x_ticks = np.arange(num_vars)
    plt.xticks(x_ticks, tick_labels, fontsize = tick_font_size, rotation = 90)
    y_ticks = np.arange(num_vars)
    plt.yticks(y_ticks, tick_labels, fontsize = tick_font_size)
    # put all of the options chosen above to use and create the correlation figure
    for i in range(len(labels)):
        for j in range(len(labels)):
            text = ax.text(i, j, str(round(data.values[i][j],2)),  
                           fontsize= val_font_size, ha="center",   
                           va="center", color = "w")
    title_font = {"fontname":"Times New Roman"}  
    plt.title("Correlation", fontsize = 50, **title_font)  
    
             # print(i, labels[i], j, labels[j], data.values[i][j])
    cbar = fig.colorbar(im)
    plt.show()
    if pp != None:
        pp.savefig(fig, bbox_inches="tight")
    plt.close()

corr_data = data_y.corr()
corr_matrix_heatmap(data_y.corr())

# %% [markdown]
# How has the correlation between each variable changed? Why do you think the correlation changes after calculate the year-over-year percent change?

# %% [markdown]
# Nominal GDP year over year growth and price level year over year growth are strongly correlated in both the charts. The federal funds effective rate is not correlated to any of these categories, while the other original correlations are very strong.
# The correlations change so much from the graphs because the change in percentage of year over year is much differenct than how the overall trends are correlated. Each sections year over year numbers can change drastically but overall the trend for the big picture is still similar to the other variables.
